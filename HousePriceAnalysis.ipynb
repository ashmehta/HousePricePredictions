# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('/Users/akshitmehta/Desktop/HousePricePrediction/American_Housing_Data_20231209.csv')
data.head()
# Out:
#    Zip Code      Price  Beds  Baths  Living Space                Address  \
# 0     10013  3999000.0     2      3          1967      74 GRAND ST APT 3
# 1     10013  3999000.0     2      3          1967      74 GRAND ST APT 3
# 2     10014  1650000.0     1      1           718  140 CHARLES ST APT 4D
# 3     10014   760000.0     3      2          1538            38 JONES ST
# 4     10014  1100000.0     1      1           600   81 BEDFORD ST APT 3F
#
#        City     State  Zip Code Population  Zip Code Density    County  \
# 0  New York  New York                29563           20967.9  New York
# 1  New York  New York                29563           20967.9  New York
# 2  New York  New York                29815           23740.9  New York
# 3  New York  New York                29815           23740.9  New York
# 4  New York  New York                29815           23740.9  New York
#
#    Median Household Income  Latitude  Longitude
# 0                 370046.0  40.72001  -74.00472
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39981 entries, 0 to 39980
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Zip Code                 39981 non-null  int64
#  1   Price                    39981 non-null  float64
#  2   Beds                     39981 non-null  int64
#  3   Baths                    39981 non-null  int64
#  4   Living Space             39981 non-null  int64
#  5   Address                  39981 non-null  object
#  6   City                     39981 non-null  object
#  7   State                    39981 non-null  object
#  8   Zip Code Population      39981 non-null  int64
#  9   Zip Code Density         39981 non-null  float64
#  10  County                   39981 non-null  object
#  11  Median Household Income  39979 non-null  float64
#  12  Latitude                 39981 non-null  float64
#  13  Longitude                39981 non-null  float64
# ...

# %%
#Checking for Null Values
data.isna().sum()
# Out:
# Zip Code                   0
# Price                      0
# Beds                       0
# Baths                      0
# Living Space               0
# Address                    0
# City                       0
# State                      0
# Zip Code Population        0
# Zip Code Density           0
# County                     0
# Median Household Income    2
# Latitude                   0
# Longitude                  0
# dtype: int64

# %%
#Handling Null Values
data.dropna(inplace=True)

# %%
#Checking to make sure Null Values have been removed
data.isna().sum()
# Out:
# Zip Code                   0
# Price                      0
# Beds                       0
# Baths                      0
# Living Space               0
# Address                    0
# City                       0
# State                      0
# Zip Code Population        0
# Zip Code Density           0
# County                     0
# Median Household Income    0
# Latitude                   0
# Longitude                  0
# dtype: int64

# %%
#Checking correlation between Price and Living Space
plt.figure(figsize=(12,6))
sns.scatterplot(data=data, x= 'Living Space', y='Price', alpha = 0.5)
plt.title('Price Vs Living Space')
plt.xlabel('Living Space')
plt.ylabel('Price')
plt.show()

# %%
#Checking correlation between Price and Beds
plt.figure(figsize=(12,6))
sns.scatterplot(data=data, x= 'Beds', y='Price', alpha = 0.5)
plt.title('Price Vs Number of Beds')
plt.xlabel('Beds')
plt.ylabel('Price')
plt.show()

# %%
#Checking correlation between Price and Baths
plt.figure(figsize=(12,6))
sns.scatterplot(data=data, x= 'Baths', y='Price', alpha = 0.5)
plt.title('Price Vs Number of Bathrooms')
plt.xlabel('Baths')
plt.ylabel('Price')
plt.show()

# %%
#Checking correlation between Price and City
plt.figure(figsize=(40,16))
sns.barplot(data=data, x= 'City', y='Price')
plt.title('Price Vs City')
plt.xlabel('City')
plt.ylabel('Price')
plt.xticks(rotation=90, fontsize=12)
plt.tight_layout()
plt.show()

# %%
#Checking correlation between Price and State
plt.figure(figsize=(20,6))
sns.barplot(data=data, x= 'State', y='Price')
plt.title('Price Vs State')
plt.xlabel('State')
plt.ylabel('Price')
plt.xticks(rotation=45, fontsize=8)
plt.tight_layout()
plt.show()

# %%
#Check for outliers
plt.figure(figsize=(20,6))
sns.boxplot(data=data, x= 'State', y='Price')
plt.title('Price Vs State')
plt.xlabel('State')
plt.ylabel('Price')
plt.xticks(rotation=45, fontsize=8)
plt.tight_layout()
plt.show()
